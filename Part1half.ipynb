# %% [markdown]
# <a href="https://colab.research.google.com/github/resh1604/SIT742/blob/master/Part1half.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wget
# Out:
# Requirement already satisfied: wget in /usr/local/lib/python3.6/dist-packages (3.2)

# %%
import wget

link_to_data = 'https://github.com/tulip-lab/sit742/raw/master/Assessment/2019/data/wine.json'
DataSet = wget.download(link_to_data)

link_to_data = 'https://github.com/tulip-lab/sit742/raw/master/Assessment/2019/data/stopwords.txt'

DataSet = wget.download(link_to_data)

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
import re
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.probability import *
from itertools import chain
#from tqdm import tqdm
import codecs

# %%
nltk.download('punkt')
nltk.download('reuters')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package reuters to /root/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# True

# %%
file = 'wine.json'

# %%
df = pd.read_json(file, orient='columns')
#df.head(10)
#print(df)
#print(df.to_json(orient='index', lines='True'))
df

# %%
data1 = df[['description']]
data1

# %%
data2 =data1.loc[:,].tail(100)
data2

# %%
data2.iloc[0,0]
# Out:
# 'A reticent nose on this wine tells only of earth and faint citrus at this point. The uncompromisingly dry palate however, is perfumed with conifer and citrus zest around a fluid, concentrated center. The tart, super-clean lemon finish tingles enticingly.'

# %%
data3 = []
for index, row in data2.iterrows():
    data3.append(row['description'].lower())
    #print(ans)
    
    with open('your_file1.txt', 'w') as f:
      for item in data3:
        f.write("%s\n" % item)
    #print(row['description'])

# %%
data4 = ''.join(map(str, data3))
data4
# Out:
# "a reticent nose on this wine tells only of earth and faint citrus at this point. the uncompromisingly dry palate however, is perfumed with conifer and citrus zest around a fluid, concentrated center. the tart, super-clean lemon finish tingles enticingly.almost like liquid cherry pie—but not sweet—this medium-bodied wine smells like the red fruit and baking spices, and tastes fresh and juicy with both red and sour cherries. it has good heft on the palate due to firm but light tannins and supportive acidity for balance.the middle wine in the trilogy of wines from the molinié family at ponzac, this is a ripe wine that has density, some firm tannins and rich black-plum fruit flavors. it is concentrated and firm at first and then fills out with the richness. drink this wine from 2018.while blossom and melon aromas on this gewürztraminer are subdued, the palate is a veritable explosion of jasmine, lychee and grapefruit flavors. silky, rich and mouth-filling, it's balanced neatly by fresh citrus acidity and a bold, phenolic finish.the gelin family has produced a rich style of wine, full of red-berry and cherry fruit. the wine is concentrated and full-bodied, giving a deliciously ripe character. the tannins are there adding support and extra density. drink now.this is a delicious, ripe and fruity wine that comes from the south of beaujolais. it has ripe red-berry fruits and soft tannins allied to a juicy acidity that keeps it all fresh. drink now.an open and inviting scent of ripe pear is freshened by an impression of wet pebbles, cold stone and citrus. the palate is textured and expressive, giving a broader canvas to these fruity, fresh flavors that have a lovely edge of gentle bitterness. the palate finishes just off dry.light in color and nuanced in oak, this full-bodied beauty doesn't hold back on richness, allowing plenty of room for an expanse of salted caramel, pineapple and preserved lemon. layered and robust throughout the midpalate, it lightens up on the intensity through a crisp finish.this wine is a blend of 45% grenache, 37% syrah and 18% mourvèdre, coming from boushey, pepper bridge, olsen and minnick vineyards. the aromas pop with notes of clove, orange peel, black pepper, funk and red and blue berries. the palate is lithe, pure and focused, with a pleasing mouthfeel and sense of balance to the citrus and blue-fruit flavors.apple blossom intrigues on the nose of this light-bodied, low-oaked white. it's both steely and revealing, showing succulent mango, peach and pear. the acidity is lively and balanced.this verdejo smells like citrus fruits and wild field grass, with a hint of feline aroma. crisp and fresh, it offers flavors of melon, nectarine and nettle. a long, slightly salty finish is braced by bright acidity. drink right away, if possible.this wine is mostly cabernet sauvignon (78%), with the rest equal parts cabernet franc and merlot. aromas of barrel spice, cedar, green herbs and black fruit are followed by tightly coiled fruit and barrel flavors that need some time to settle in.a tropical tone of grilled pineapple adds breadth to the nose and mouth of this lush yet well-balanced wine. scents of yellow flowers, musk melon and sweet smoke unfold on the nose, while the palate shines in rich waves of toasted brioche, baked apple and clementine oil. it's medium weight, with a plush texture that's cut by citrusy acidity. drink now–2019.after 23 months in barrel, this viura-malvasia blend shows a yellow color and dry resiny oak-based aromas along with apple in the backdrop. round and slightly oily in texture, this tastes of salted nuts and baked apple on a woody base. oaky salty flavors persist on the finish.lemon-lime soda aromas meet with orange blossom, toast, lanolin and steel on the nose of this voluptuous yet well-defined bottling. it's tightly wound on the palate, with lemon, grapefruit rind and crushed limestone flavors, bound by a chalky texture, showing deft restraint for a roussanne.full aromas of toasty o ...

# %%
data5 = re.sub(r'[^\w]', ' ', data4)
data5
# Out:
# 'a reticent nose on this wine tells only of earth and faint citrus at this point  the uncompromisingly dry palate however  is perfumed with conifer and citrus zest around a fluid  concentrated center  the tart  super clean lemon finish tingles enticingly almost like liquid cherry pie but not sweet this medium bodied wine smells like the red fruit and baking spices  and tastes fresh and juicy with both red and sour cherries  it has good heft on the palate due to firm but light tannins and supportive acidity for balance the middle wine in the trilogy of wines from the molinié family at ponzac  this is a ripe wine that has density  some firm tannins and rich black plum fruit flavors  it is concentrated and firm at first and then fills out with the richness  drink this wine from 2018 while blossom and melon aromas on this gewürztraminer are subdued  the palate is a veritable explosion of jasmine  lychee and grapefruit flavors  silky  rich and mouth filling  it s balanced neatly by fresh citrus acidity and a bold  phenolic finish the gelin family has produced a rich style of wine  full of red berry and cherry fruit  the wine is concentrated and full bodied  giving a deliciously ripe character  the tannins are there adding support and extra density  drink now this is a delicious  ripe and fruity wine that comes from the south of beaujolais  it has ripe red berry fruits and soft tannins allied to a juicy acidity that keeps it all fresh  drink now an open and inviting scent of ripe pear is freshened by an impression of wet pebbles  cold stone and citrus  the palate is textured and expressive  giving a broader canvas to these fruity  fresh flavors that have a lovely edge of gentle bitterness  the palate finishes just off dry light in color and nuanced in oak  this full bodied beauty doesn t hold back on richness  allowing plenty of room for an expanse of salted caramel  pineapple and preserved lemon  layered and robust throughout the midpalate  it lightens up on the intensity through a crisp finish this wine is a blend of 45  grenache  37  syrah and 18  mourvèdre  coming from boushey  pepper bridge  olsen and minnick vineyards  the aromas pop with notes of clove  orange peel  black pepper  funk and red and blue berries  the palate is lithe  pure and focused  with a pleasing mouthfeel and sense of balance to the citrus and blue fruit flavors apple blossom intrigues on the nose of this light bodied  low oaked white  it s both steely and revealing  showing succulent mango  peach and pear  the acidity is lively and balanced this verdejo smells like citrus fruits and wild field grass  with a hint of feline aroma  crisp and fresh  it offers flavors of melon  nectarine and nettle  a long  slightly salty finish is braced by bright acidity  drink right away  if possible this wine is mostly cabernet sauvignon  78    with the rest equal parts cabernet franc and merlot  aromas of barrel spice  cedar  green herbs and black fruit are followed by tightly coiled fruit and barrel flavors that need some time to settle in a tropical tone of grilled pineapple adds breadth to the nose and mouth of this lush yet well balanced wine  scents of yellow flowers  musk melon and sweet smoke unfold on the nose  while the palate shines in rich waves of toasted brioche  baked apple and clementine oil  it s medium weight  with a plush texture that s cut by citrusy acidity  drink now 2019 after 23 months in barrel  this viura malvasia blend shows a yellow color and dry resiny oak based aromas along with apple in the backdrop  round and slightly oily in texture  this tastes of salted nuts and baked apple on a woody base  oaky salty flavors persist on the finish lemon lime soda aromas meet with orange blossom  toast  lanolin and steel on the nose of this voluptuous yet well defined bottling  it s tightly wound on the palate  with lemon  grapefruit rind and crushed limestone flavors  bound by a chalky texture  showing deft restraint for a roussanne full aromas of toasty o ...

# %%
with open('stopwords.txt') as f:
    stop_words = f.read().splitlines()
stop_words = set(stop_words)
stop_words

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
  
word_tokens = word_tokenize(data5) 
  
filtered_sentence = [w for w in word_tokens if not w in stop_words] 
  
filtered_sentence = [] 
  
for w in word_tokens: 
    if w not in stop_words: 
        filtered_sentence.append(w) 
  
print(word_tokens) 
print(filtered_sentence)
# Out:
# ['a', 'reticent', 'nose', 'on', 'this', 'wine', 'tells', 'only', 'of', 'earth', 'and', 'faint', 'citrus', 'at', 'this', 'point', 'the', 'uncompromisingly', 'dry', 'palate', 'however', 'is', 'perfumed', 'with', 'conifer', 'and', 'citrus', 'zest', 'around', 'a', 'fluid', 'concentrated', 'center', 'the', 'tart', 'super', 'clean', 'lemon', 'finish', 'tingles', 'enticingly', 'almost', 'like', 'liquid', 'cherry', 'pie', 'but', 'not', 'sweet', 'this', 'medium', 'bodied', 'wine', 'smells', 'like', 'the', 'red', 'fruit', 'and', 'baking', 'spices', 'and', 'tastes', 'fresh', 'and', 'juicy', 'with', 'both', 'red', 'and', 'sour', 'cherries', 'it', 'has', 'good', 'heft', 'on', 'the', 'palate', 'due', 'to', 'firm', 'but', 'light', 'tannins', 'and', 'supportive', 'acidity', 'for', 'balance', 'the', 'middle', 'wine', 'in', 'the', 'trilogy', 'of', 'wines', 'from', 'the', 'molinié', 'family', 'at', 'ponzac', 'this', 'is', 'a', 'ripe', 'wine', 'that', 'has', 'density', 'some', 'firm', 'tannins', 'and', 'rich', 'black', 'plum', 'fruit', 'flavors', 'it', 'is', 'concentrated', 'and', 'firm', 'at', 'first', 'and', 'then', 'fills', 'out', 'with', 'the', 'richness', 'drink', 'this', 'wine', 'from', '2018', 'while', 'blossom', 'and', 'melon', 'aromas', 'on', 'this', 'gewürztraminer', 'are', 'subdued', 'the', 'palate', 'is', 'a', 'veritable', 'explosion', 'of', 'jasmine', 'lychee', 'and', 'grapefruit', 'flavors', 'silky', 'rich', 'and', 'mouth', 'filling', 'it', 's', 'balanced', 'neatly', 'by', 'fresh', 'citrus', 'acidity', 'and', 'a', 'bold', 'phenolic', 'finish', 'the', 'gelin', 'family', 'has', 'produced', 'a', 'rich', 'style', 'of', 'wine', 'full', 'of', 'red', 'berry', 'and', 'cherry', 'fruit', 'the', 'wine', 'is', 'concentrated', 'and', 'full', 'bodied', 'giving', 'a', 'deliciously', 'ripe', 'character', 'the', 'tannins', 'are', 'there', 'adding', 'support', 'and', 'extra', 'density', 'drink', 'now', 'this', 'is', 'a', 'delicious', 'ripe', 'and', 'fruity', 'wine', 'that', 'comes', 'from', 'the', 'south', 'of', 'beaujolais', 'it', 'has', 'ripe', 'red', 'berry', 'fruits', 'and', 'soft', 'tannins', 'allied', 'to', 'a', 'juicy', 'acidity', 'that', 'keeps', 'it', 'all', 'fresh', 'drink', 'now', 'an', 'open', 'and', 'inviting', 'scent', 'of', 'ripe', 'pear', 'is', 'freshened', 'by', 'an', 'impression', 'of', 'wet', 'pebbles', 'cold', 'stone', 'and', 'citrus', 'the', 'palate', 'is', 'textured', 'and', 'expressive', 'giving', 'a', 'broader', 'canvas', 'to', 'these', 'fruity', 'fresh', 'flavors', 'that', 'have', 'a', 'lovely', 'edge', 'of', 'gentle', 'bitterness', 'the', 'palate', 'finishes', 'just', 'off', 'dry', 'light', 'in', 'color', 'and', 'nuanced', 'in', 'oak', 'this', 'full', 'bodied', 'beauty', 'doesn', 't', 'hold', 'back', 'on', 'richness', 'allowing', 'plenty', 'of', 'room', 'for', 'an', 'expanse', 'of', 'salted', 'caramel', 'pineapple', 'and', 'preserved', 'lemon', 'layered', 'and', 'robust', 'throughout', 'the', 'midpalate', 'it', 'lightens', 'up', 'on', 'the', 'intensity', 'through', 'a', 'crisp', 'finish', 'this', 'wine', 'is', 'a', 'blend', 'of', '45', 'grenache', '37', 'syrah', 'and', '18', 'mourvèdre', 'coming', 'from', 'boushey', 'pepper', 'bridge', 'olsen', 'and', 'minnick', 'vineyards', 'the', 'aromas', 'pop', 'with', 'notes', 'of', 'clove', 'orange', 'peel', 'black', 'pepper', 'funk', 'and', 'red', 'and', 'blue', 'berries', 'the', 'palate', 'is', 'lithe', 'pure', 'and', 'focused', 'with', 'a', 'pleasing', 'mouthfeel', 'and', 'sense', 'of', 'balance', 'to', 'the', 'citrus', 'and', 'blue', 'fruit', 'flavors', 'apple', 'blossom', 'intrigues', 'on', 'the', 'nose', 'of', 'this', 'light', 'bodied', 'low', 'oaked', 'white', 'it', 's', 'both', 'steely', 'and', 'revealing', 'showing', 'succulent', 'mango', 'peach', 'and', 'pear', 'the', 'acidity', 'is', 'lively', 'and', 'balanced', 'this', 'verdejo', 'smells', 'like', 'citrus', 'fruits', 'and', 'wild', 'field', 'grass', 'with', 'a', 'hint', 'of', 'feline', 'aroma', 'crisp', 'and', 'fresh', 'it' ...
# ['reticent', 'nose', 'wine', 'tells', 'earth', 'faint', 'citrus', 'point', 'uncompromisingly', 'dry', 'palate', 'perfumed', 'conifer', 'citrus', 'zest', 'fluid', 'concentrated', 'center', 'tart', 'super', 'clean', 'lemon', 'finish', 'tingles', 'enticingly', 'liquid', 'cherry', 'pie', 'sweet', 'medium', 'bodied', 'wine', 'smells', 'red', 'fruit', 'baking', 'spices', 'tastes', 'fresh', 'juicy', 'red', 'sour', 'cherries', 'good', 'heft', 'palate', 'due', 'firm', 'light', 'tannins', 'supportive', 'acidity', 'balance', 'middle', 'wine', 'trilogy', 'wines', 'molinié', 'family', 'ponzac', 'ripe', 'wine', 'density', 'firm', 'tannins', 'rich', 'black', 'plum', 'fruit', 'flavors', 'concentrated', 'firm', 'fills', 'richness', 'drink', 'wine', '2018', 'blossom', 'melon', 'aromas', 'gewürztraminer', 'subdued', 'palate', 'veritable', 'explosion', 'jasmine', 'lychee', 'grapefruit', 'flavors', 'silky', 'rich', 'mouth', 'filling', 'balanced', 'neatly', 'fresh', 'citrus', 'acidity', 'bold', 'phenolic', 'finish', 'gelin', 'family', 'produced', 'rich', 'style', 'wine', 'full', 'red', 'berry', 'cherry', 'fruit', 'wine', 'concentrated', 'full', 'bodied', 'giving', 'deliciously', 'ripe', 'character', 'tannins', 'adding', 'support', 'extra', 'density', 'drink', 'delicious', 'ripe', 'fruity', 'wine', 'south', 'beaujolais', 'ripe', 'red', 'berry', 'fruits', 'soft', 'tannins', 'allied', 'juicy', 'acidity', 'fresh', 'drink', 'open', 'inviting', 'scent', 'ripe', 'pear', 'freshened', 'impression', 'wet', 'pebbles', 'cold', 'stone', 'citrus', 'palate', 'textured', 'expressive', 'giving', 'broader', 'canvas', 'fruity', 'fresh', 'flavors', 'lovely', 'edge', 'gentle', 'bitterness', 'palate', 'finishes', 'dry', 'light', 'color', 'nuanced', 'oak', 'full', 'bodied', 'beauty', 'doesn', 'hold', 'back', 'richness', 'allowing', 'plenty', 'room', 'expanse', 'salted', 'caramel', 'pineapple', 'preserved', 'lemon', 'layered', 'robust', 'midpalate', 'lightens', 'intensity', 'crisp', 'finish', 'wine', 'blend', '45', 'grenache', '37', 'syrah', '18', 'mourvèdre', 'coming', 'boushey', 'pepper', 'bridge', 'olsen', 'minnick', 'vineyards', 'aromas', 'pop', 'notes', 'clove', 'orange', 'peel', 'black', 'pepper', 'funk', 'red', 'blue', 'berries', 'palate', 'lithe', 'pure', 'focused', 'pleasing', 'mouthfeel', 'sense', 'balance', 'citrus', 'blue', 'fruit', 'flavors', 'apple', 'blossom', 'intrigues', 'nose', 'light', 'bodied', 'low', 'oaked', 'white', 'steely', 'revealing', 'showing', 'succulent', 'mango', 'peach', 'pear', 'acidity', 'lively', 'balanced', 'verdejo', 'smells', 'citrus', 'fruits', 'wild', 'field', 'grass', 'hint', 'feline', 'aroma', 'crisp', 'fresh', 'offers', 'flavors', 'melon', 'nectarine', 'nettle', 'long', 'slightly', 'salty', 'finish', 'braced', 'bright', 'acidity', 'drink', 'wine', 'cabernet', 'sauvignon', '78', 'rest', 'equal', 'parts', 'cabernet', 'franc', 'merlot', 'aromas', 'barrel', 'spice', 'cedar', 'green', 'herbs', 'black', 'fruit', 'tightly', 'coiled', 'fruit', 'barrel', 'flavors', 'time', 'settle', 'tropical', 'tone', 'grilled', 'pineapple', 'adds', 'breadth', 'nose', 'mouth', 'lush', 'balanced', 'wine', 'scents', 'yellow', 'flowers', 'musk', 'melon', 'sweet', 'smoke', 'unfold', 'nose', 'palate', 'shines', 'rich', 'waves', 'toasted', 'brioche', 'baked', 'apple', 'clementine', 'oil', 'medium', 'weight', 'plush', 'texture', 'cut', 'citrusy', 'acidity', 'drink', '2019', '23', 'months', 'barrel', 'viura', 'malvasia', 'blend', 'shows', 'yellow', 'color', 'dry', 'resiny', 'oak', 'based', 'aromas', 'apple', 'backdrop', 'round', 'slightly', 'oily', 'texture', 'tastes', 'salted', 'nuts', 'baked', 'apple', 'woody', 'base', 'oaky', 'salty', 'flavors', 'persist', 'finish', 'lemon', 'lime', 'soda', 'aromas', 'meet', 'orange', 'blossom', 'toast', 'lanolin', 'steel', 'nose', 'voluptuous', 'defined', 'bottling', 'tightly', 'wound', 'palate', 'lemon', 'grapefruit', 'rind', 'crushed', 'limestone', 'flavors', 'bound', 'chalky', 'texture', 'showing', 'deft', 'restraint', 'r ...
